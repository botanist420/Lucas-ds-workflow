# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os

# %%
file_path = "fitness_class.csv"

df = pd.read_csv(file_path)
# Out:
#   day_of_week time class_category  class_capacity  days_before  attendance  \
# 0         Wed   AM           Yoga              15            1           8
# 1         Sun   PM           Aqua              15            3           8
# 2         Mon   AM           Aqua              15            5          10
# 3         Sun   PM       Strength              25            3          18
# 4         Mon   AM           Yoga              15            5          10
#
#     age  new_students  over_6_month
# 0  31.1             6             4
# 1  27.0             7             8
# 2  22.4             8             7
# 3  23.5             7             9
# 4  29.8             5             7

# %%
print(df.columns)


print(f"-----\
      \nHow many columns are there in this dataset: {len(df.columns)}")
# Out:
# Index(['day_of_week', 'time', 'class_category', 'class_capacity',
#        'days_before', 'attendance', 'age', 'new_students', 'over_6_month'],
#       dtype='object')
# -----
# How many columns are there in this dataset: 9

# %%
df.head()
# Out:
#   day_of_week time class_category  class_capacity  days_before  attendance  \
# 0         Wed   AM           Yoga              15            1           8
# 1         Sun   PM           Aqua              15            3           8
# 2         Mon   AM           Aqua              15            5          10
# 3         Sun   PM       Strength              25            3          18
# 4         Mon   AM           Yoga              15            5          10
#
#     age  new_students  over_6_month
# 0  31.1             6             4
# 1  27.0             7             8
# 2  22.4             8             7
# 3  23.5             7             9
# 4  29.8             5             7

# %%
df.class_category.value_counts().plot(kind="bar", color="coral")
# Out:
# <AxesSubplot:>

# %%
print(df.describe())
sns.pairplot(df, kind="kde")
# Out:
#        class_capacity  days_before  attendance         age  new_students  \
# count      765.000000   765.000000  765.000000  765.000000    765.000000
# mean        17.542484     2.547712    9.563399   29.092680      5.917647
# std          4.365481     1.355379    3.896598    5.912063      1.789224
# min         15.000000     1.000000    4.000000    8.300000      1.000000
# 25%         15.000000     1.000000    7.000000   25.300000      5.000000
# 50%         15.000000     2.000000    9.000000   29.000000      6.000000
# 75%         25.000000     4.000000   11.000000   33.200000      7.000000
# max         26.000000     5.000000   21.000000   48.800000     11.000000
#
#        over_6_month
# count    765.000000
# mean       7.577778
# std        1.974518
# min        2.000000
# 25%        6.000000
# 50%        8.000000
# 75%        9.000000
# max       13.000000

# %%
print(df.class_category.unique())

df[df["class_category"] == "Strength"]
# Out:
# ['Yoga' 'Aqua' 'Strength' 'HIIT' 'Cycling']
#     day_of_week time class_category  class_capacity  days_before  attendance  \
# 3           Sun   PM       Strength              25            3          18
# 8           Wed   PM       Strength              25            2          20
# 12          Sat   PM       Strength              15            2           9
# 20          Tue   PM       Strength              15            1           8
# 23          Sun   AM       Strength              15            3          11
# ..          ...  ...            ...             ...          ...         ...
# 751         Wed   PM       Strength              25            3          19
# 752         Sun   AM       Strength              15            2          10
# 755         Wed   PM       Strength              15            3           5
# 759         Fri   AM       Strength              15            4           6
# 763         Sun   PM       Strength              15            1           7
#
# ...

# %%
df.attendance.plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.age.plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.groupby("class_category")["attendance"].mean()
# Out:
# class_category
# Aqua        9.537500
# Cycling     9.130769
# HIIT        9.306569
# Strength    9.760736
# Yoga        9.925714
# Name: attendance, dtype: float64

# %%
df.groupby(["day_of_week", "time"])["attendance"].mean().unstack().sort_values("AM", ascending=False)
# Out:
# time               AM         PM
# day_of_week
# Fri          9.878049   9.648148
# Sun          9.776119  10.083333
# Tue          9.672414  10.129032
# Sat          9.500000   9.115385
# Mon          9.263158   9.555556
# Wed          9.129630   9.822581
# Thu          9.000000   9.296875
